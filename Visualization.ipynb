# %%
import pandas as pd
from pandas_datareader import data
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## .plot()

# %%
bb=data.DataReader(name='BBRY', data_source='google', start='2007-07-01', end='2008-12-31')
bb.head(3)
# Out:
# /Users/matt/.local/share/virtualenvs/mini-assessment-13dtSyk6/lib/python3.6/site-packages/pandas_datareader/google/daily.py:40: UnstableAPIWarning:
# The Google Finance API has not been stable since late 2017. Requests seem
# to fail at random. Failure is especially common when bulk downloading.
#
#   warnings.warn(UNSTABLE_WARNING, UnstableAPIWarning)
#               Open    High     Low   Close    Volume
# Date
# 2007-07-02  201.97  215.40  199.07  214.26  18888168
# 2007-07-03  215.48  216.89  206.40  207.94   8835540
# 2007-07-05  216.46  217.30  209.01  216.19  13251409

# %%
bb.plot()

# %% [markdown]
# usually only do .plot() on a single column

# %%
bb[['High','Low']].plot()

# %% [markdown]
# ## Modify aesthetics

# %%
plt.style.available
# Out:
# ['_classic_test',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn')
bb.plot(y='Close')

# %% [markdown]
# ## Bar charts

# %%
google = data.DataReader(name='GOOG', data_source='google', start='2004-01-01',end='2016-12-12')
google
# Out:
# /Users/matt/.local/share/virtualenvs/mini-assessment-13dtSyk6/lib/python3.6/site-packages/pandas_datareader/google/daily.py:40: UnstableAPIWarning:
# The Google Finance API has not been stable since late 2017. Requests seem
# to fail at random. Failure is especially common when bulk downloading.
#
#   warnings.warn(UNSTABLE_WARNING, UnstableAPIWarning)
#               Open    High     Low   Close     Volume
# Date
# 2004-08-19   49.96   51.98   47.93   50.12        NaN
# 2004-08-20   50.69   54.49   50.20   54.10        NaN
# 2004-08-23   55.32   56.68   54.47   54.65        NaN
# 2004-08-24   55.56   55.74   51.73   52.38        NaN
# 2004-08-25   52.43   53.95   51.89   52.95        NaN
# 2004-08-26   52.42   53.92   52.28   53.90        NaN
# 2004-08-27   54.00   54.26   52.79   53.02        NaN
# 2004-08-30   52.69   52.69   50.95   50.95        NaN
# 2004-08-31   51.11   51.80   51.03   51.13        NaN
# 2004-09-01   51.30   51.43   49.79   50.07        NaN
# ...

# %%
def rank_performance(stock_price):
    if stock_price <= 200:
        return "Poor"
    elif stock_price <= 500:
        return "Satisfactory"
    else:
        return "Stellar"

# %%
plt.style.use('ggplot')
google["Close"].apply(rank_performance).value_counts().plot(kind='barh')

# %% [markdown]
# ## pie chart

# %% [markdown]
# usuful for showing how seperate data makes a whole

# %%
apple = data.DataReader(name='AAPL', data_source='google', start='2012-01-01', end='2016-12-12')
apple.head(3)
# Out:
# /Users/matt/.local/share/virtualenvs/mini-assessment-13dtSyk6/lib/python3.6/site-packages/pandas_datareader/google/daily.py:40: UnstableAPIWarning:
# The Google Finance API has not been stable since late 2017. Requests seem
# to fail at random. Failure is especially common when bulk downloading.
#
#   warnings.warn(UNSTABLE_WARNING, UnstableAPIWarning)
#              Open   High    Low  Close    Volume
# Date
# 2012-01-03  58.49  58.93  58.43  58.75  75564699
# 2012-01-04  58.57  59.24  58.47  59.06  65061108
# 2012-01-05  59.28  59.79  58.95  59.72  67816805

# %%
apple['Close'].mean()
# Out:
# 93.12191967871486

# %%
def rank_performance(stock_price):
    if stock_price >= 93.12191967871486:
        return "Above average"
    else:
        return "Below average"

# %%
apple['Close'].apply(rank_performance).value_counts().plot(kind='pie', legend=True)

# %% [markdown]
# ## Histogram

# %% [markdown]
# good at showing distributions of data

# %%
def custom_round(stock_price):
    return int(stock_price / 100.0) * 100

# %%
custom_round(535.6)
# Out:
# 500

# %%
google['High'].apply(custom_round).value_counts().sort_index()
# Out:
# 0       157
# 100     414
# 200    1129
# 300     449
# 400     159
# 500     414
# 600     107
# 700     264
# 800       8
# Name: High, dtype: int64

# %%
google['High'].apply(custom_round).nunique()
# Out:
# 9

# %%
google['High'].apply(custom_round).plot(kind='hist', bins=9)
