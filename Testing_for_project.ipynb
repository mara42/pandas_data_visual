# %%
import pandas as pd

# %%
election = pd.read_csv('/Users/matt/Downloads/cmarekavoindataavoindata1.csv', ';')
swimming_pool = pd.read_csv('/Users/matt/Downloads/Uimahallien kÑyntitapahtumatv2.csv', ';', encoding='ISO-8859-1')

# %%
election
swimming_pool
# swimming_pool['Product'].value_counts()
# Out:
#      julkaisu_pvm                                          tuotenimi  \
# 0      23.04.2008                         Zhejiang Tiantian Electric
# 1      23.04.2008                                         Speed Link
# 2      23.04.2008                                 Shining Blick/Esvi
# 3      23.04.2008                                           MicroOne
# 4      23.04.2008                       a/s shaver power cord coiled
# 5      23.04.2008                                    6 410411 852466
# 6      23.04.2008                                              Airam
# 7      23.04.2008                                              Sumec
# 8      23.04.2008                                       KF (Energy+)
# 9      10.04.2008                                  Rokomera Tukku Oy
# 10     10.04.2008                             Ningbo Linsheng (Opal)
# 11     10.04.2008                             Denver MT748DVBT MPEG4
# 12     10.04.2008                                       Etman (Opal)
# ...
